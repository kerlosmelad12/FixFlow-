# %%
import requests

payload = {
    "query": """
<p>I'm getting in an <code>int</code> with a 6 digit value. I want to display it as a <code>String</code> with a decimal point (.) at 2 digits from the end of <code>int</code>. I wanted to use a <code>float</code> but was suggested to use <code>String</code> for a better display output (instead of <code>1234.5</code> will be <code>1234.50</code>). Therefore, I need a function that will take an <code>int</code> as parameter and return the properly formatted <code>String</code> with a decimal point 2 digits from the end.</p>

<p>Say:</p>

<pre><code>int j= 123456 
Integer.toString(j); 

//processing...

//output : 1234.56
</code></pre>



"""
}

resp = requests.post(
    "http://127.0.0.1:5000/Fixflow-V1/data/upload/",
    json=payload
)

print(resp.status_code)
print(resp.json())
# Out:
# 200
# {'result': 'your error is approved', 'error': {'error_signature': 'need function to format int as string with decimal point 2 digits from end', 'error_title': 'Formatting Integer as String with Decimal Point', 'error_type': 'unknown', 'tags': ['java', 'string-formatting', 'integer', 'decimal-point']}, 'job_id': '6a71dcaa48d210e719ff2393'}
