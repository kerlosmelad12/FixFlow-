# %%
import requests

payload = {
    "query": """
Check if a string contains a string in C++ I have a variable of type std::string . I want to check if it contains a certain std::string . How would I do that? Is there a function that returns true if the string is found, and false if it isn't? and the Tags: 'c++' and 'string' and 'substring'"""
}

resp = requests.post(
    "http://127.0.0.1:5000/Fixflow-V1/data/upload/",
    json=payload
)

print(resp.status_code)
print(resp.json())
# Out:
# 200
# {'result': 'your error is approved', 'error': {'tags': ['c++', 'string', 'substring'], 'error_type': 'unknown', 'error_title': 'Check if String Contains Substring in C++', 'error_signature': 'check if a string contains a string in c++'}, 'job_id': '6a71f8ae4f7456928c57f3f9'}
