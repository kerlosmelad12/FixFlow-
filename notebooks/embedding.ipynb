# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('D:\\my projects\\FixFlow-\\notebooks\\data\\data.csv')
data.head()
# Out:
#                                                 tags  answer_count  score  \
# 0            ['android', 'android-studio', 'kotlin']            55    190
# 1  ['android', 'google-play', 'android-manifest',...             7    190
# 2                                   ['mysql', 'svn']            15    189
# 3  ['linq', 'linq-to-sql', 'linq-to-entities', 'l...             9    189
# 4  ['java', 'exception', 'return', 'try-catch-fin...             6    189
#
#                    creation_date  question_id  \
# 0  1970-01-01 00:00:01.589490945     61807520
# 1  1970-01-01 00:00:01.658868456     73129574
# 2  1970-01-01 00:00:01.218228602         6371
# 3  1970-01-01 00:00:01.219157443        16322
# 4  1970-01-01 00:00:01.220757358        48088
#
#                                                title  \
# 0  How to fix ERROR: No signature of method: buil...
# 1  You can&#39;t submit updates as some informati...
# 2  How do you manage databases in development, te...
# ...

# %%
#I am building an AI-powered error resolution system called FixFlow.

Generate a complete production-ready Python module that creates a Knowledge Base layer for programming questions and answers.

Requirements:

Architecture:
- MongoDB as the main database
- Qdrant as the Vector Database
- Pydantic v2 models
- Motor async MongoDB client
- Async code only

The system should store programming questions and answers separately from user queries.

Design the following:

1. MongoDB Collection:
   knowledge_base

Each document represents ONE question-answer pair.

Fields:

- _id
- question_id
- answer_id
- title
- question
- cleaned_question
- answer
- cleaned_answer
- accepted_answer
- answer_score
- question_score
- tags
- programming_language
- technologies
- cluster_name
- error_type
- error_signature
- source
- source_url
- created_at
- updated_at
- embedding_id

2. Create the Pydantic model.

3. Create a MongoDB Model class named KnowledgeBaseModel.

Methods:

insert_document()

insert_many()

get_by_question_id()

get_by_answer_id()

get_by_cluster()

search_by_tags()

search_by_error_type()

delete_document()

update_document()

4. Create a VectorStoreModel.

Methods:

insert_embedding()

search_similar()

delete_embedding()

update_embedding()

5. Create an EmbeddingService.

Methods:

embed_question()

embed_answer()

embed_document()

6. During insertion:

Question and answer should be cleaned.

Generate embeddings.

Store document inside MongoDB.

Store embeddings inside Qdrant.

Store only embedding_id inside MongoDB.

7. Keep MongoDB as the source of truth.

Qdrant should only contain:

- id
- vector
- payload

8. Follow SOLID principles.

9. Use dependency injection.

10. Use type hints everywhere.

11. Return complete Python code with all classes.

Do not explain anything.

Only generate code.
# Out:
# d:\Anaconda\envs\ds_env\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# d:\Anaconda\envs\ds_env\lib\site-packages\transformers\utils\hub.py:128: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# d:\Anaconda\envs\ds_env\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.18) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# ...
